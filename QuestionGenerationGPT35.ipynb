# %% [markdown]
# <a href="https://colab.research.google.com/github/tubagokhan/RegNLPDataset/blob/main/QuestionGenerationGPT35.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install openai==0.28
# Out:
# Requirement already satisfied: openai==0.28 in /usr/local/lib/python3.10/dist-packages (0.28.0)
# Requirement already satisfied: requests>=2.20 in /usr/local/lib/python3.10/dist-packages (from openai==0.28) (2.31.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from openai==0.28) (4.66.2)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from openai==0.28) (3.9.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->openai==0.28) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->openai==0.28) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->openai==0.28) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->openai==0.28) (2024.2.2)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai==0.28) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai==0.28) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai==0.28) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai==0.28) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai==0.28) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai==0.28) (4.0.3)

# %%
#Execution Time 15 minutes
#Runnın on Colab CPU
#Cost 0.12 dolar

# %%
import json
import os
import openai
import time
import re


# Set environment variables for API keys
openai.api_key = "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"

def generate_question(context):
        questions = []
    #while True:  # Keep trying until successful
        try:
            response = openai.ChatCompletion.create(
                model="gpt-3.5-turbo",
                messages=[
                    {"role": "system", "content": "Your task is to generate realistic and applied questions that pertains to the provided regulatory or compliance material. Ensure that the context implicitly contains the answer to the question."},
                    {"role": "user", "content": context}
                ]
            )
            content = response.choices[0].message["content"].strip()
            # Check if the response is a question; if not, return 'None'
            questions = [q.strip() for q in content.split('\n') if q.endswith('?')]
            questions = [re.sub(r'^\d+\.\s+', '', q) for q in questions]
        except Exception as e:
            print(f"An error occurred: {e}")
            print("Retrying in 2 minutes...")
            time.sleep(120)  # Wait for 120 seconds before retrying
        print(f"Question count : {len(questions)}")
        return questions

def process_data_and_save(data, file_path):
    #for index, item in enumerate(data[:10], start=1):  # Adding enumerate to track the item number, starting from 1
    for index, item in enumerate(data[400:], start=401):  # Adding enumerate to track the item number, starting from 1
        context = item.get('Text', '').strip()
        context_id = item.get('ContextID', '').strip()
        is_title = item.get('isTitle', False)

        # Printing the item number
        print(f"Processing item number: {index}")

        if context and context_id and not is_title:
            questions = generate_question(context)
            for question in questions:
                qa_pair = {
                    "ContextID": context_id,
                    "Text": context,
                    "Question": question,
                    "isTitle": is_title
                }
                save_to_json(qa_pair, file_path)



def save_to_json(qa_pair, file_path):
    try:
        with open(file_path, 'r+') as file:
            # Read the existing data
            file_data = json.load(file)
            # Append the new QA pair
            file_data.append(qa_pair)
            # Reset file pointer to the beginning
            file.seek(0)
            # Write the updated data back to the file
            json.dump(file_data, file, indent=4)
            # Print the count of items in the JSON file
            print(f"Item count in the JSON file after save: {len(file_data)}")
    except FileNotFoundError:
        with open(file_path, 'w') as file:
            # If the file does not exist, create a new list with the QA pair and write it to the file
            json.dump([qa_pair], file, indent=4)
            # Since this is the first item, print count as 1
            print("Item count in the JSON file after save: 1")

def main():
    # Load data from JSON
    file_path = '/content/drive/Othercomputers/MBZUAI/MBZUAI/ADGM-Project/ADGM-Docs/StandardizedDocs/FSRA Rulebooks/COBS_VER15_with_titles.json'
    with open(file_path, 'r') as file:
        data = json.load(file)

    output_file_path = '/content/drive/Othercomputers/MBZUAI/MBZUAI/ADGM-Project/ADGM Docs Study/ArtificialDataset/COBS_VER15.150823_questions_contexts.json'
    process_data_and_save(data, output_file_path)

    print(f"Questions and contexts saved to {output_file_path}")

if __name__ == "__main__":
    main()
# Out:
# Processing item number: 401
# Question count : 1
# Item count in the JSON file after save: 869
# Processing item number: 402
# Question count : 4
# Item count in the JSON file after save: 870
# Item count in the JSON file after save: 871
# Item count in the JSON file after save: 872
# Item count in the JSON file after save: 873
# Processing item number: 403
# Question count : 3
# Item count in the JSON file after save: 874
# Item count in the JSON file after save: 875
# Item count in the JSON file after save: 876
# Processing item number: 404
# Processing item number: 405
# Question count : 5
# Item count in the JSON file after save: 877
# Item count in the JSON file after save: 878
# Item count in the JSON file after save: 879
# Item count in the JSON file after save: 880
# Item count in the JSON file after save: 881
# Processing item number: 406
# Question count : 2
# Item count in the JSON file after save: 882
# Item count in the JSON file after save: 883
# Processing item number: 407
# Question count : 5
# Item count in the JSON file after save: 884
# Item count in the JSON file after save: 885
# Item count in the JSON file after save: 886
# Item count in the JSON file after save: 887
# Item count in the JSON file after save: 888
# Processing item number: 408
# Question count : 5
# Item count in the JSON file after save: 889
# Item count in the JSON file after save: 890
# Item count in the JSON file after save: 891
# Item count in the JSON file after save: 892
# Item count in the JSON file after save: 893
# Processing item number: 409
# Processing item number: 410
# Question count : 5
# Item count in the JSON file after save: 894
# Item count in the JSON file after save: 895
# Item count in the JSON file after save: 896
# Item count in the JSON file after save: 897
# Item count in the JSON file after save: 898
# Processing item number: 411
# Question count : 5
# Item count in the JSON file after save: 899
# Item count in the JSON file after save: 900
# Item count in the JSON file after save: 901
# Item count in the JSON file after save: 902
# Item count in the JSON file after save: 903
# Processing item number: 412
# Question count : 1
# Item count in the JSON file after save: 904
# Processing item number: 413
# Question count : 1
# Item count in the JSON file after save: 905
# Processing item number: 414
# Question count : 4
# Item count in the JSON file after save: 906
# Item count in the JSON file after save: 907
# Item count in the JSON file after save: 908
# Item count in the JSON file after save: 909
# Processing item number: 415
# Processing item number: 416
# Question count : 2
# Item count in the JSON file after save: 910
# Item count in the JSON file after save: 911
# Processing item number: 417
# Question count : 5
# Item count in the JSON file after save: 912
# Item count in the JSON file after save: 913
# Item count in the JSON file after save: 914
# Item count in the JSON file after save: 915
# Item count in the JSON file after save: 916
# Processing item number: 418
# Processing item number: 419
# Question count : 2
# Item count in the JSON file after save: 917
# Item count in the JSON file after save: 918
# Processing item number: 420
# Question count : 2
# Item count in the JSON file after save: 919
# Item count in the JSON file after save: 920
# Processing item number: 421
# Question count : 3
# Item count in the JSON file after save: 921
# Item count in the JSON file after save: 922
# Item count in the JSON file after save: 923
# Processing item number: 422
# Processing item number: 423
# Processing item number: 424
# Question count : 5
# Item count in the JSON file after save: 924
# Item count in the JSON file after save: 925
# Item count in the JSON file after save: 926
# Item count in the JSON file after save: 927
# Item count in the JSON file after save: 928
# Processing item number: 425
# Question count : 4
# Item count in the JSON file after save: 929
# Item count in the JSON file after save: 930
# Item count in the JSON file after save: 931
# Item count in the JSON file after save: 932
# Processing item number: 426
# Question count : 3
# Item count in the JSON file after save: 933
# Item count in the JSON file after save: 934
# Item count in the JSON file after save: 935
# Processing item number: 427
# Question count : 5
# Item count in the JSON file after save: 936
# Item count in the JSON file after save: 937
# Item count in the JSON file after save: 938
# Item count in the JSON file after save: 939
# Item count in the JSON file after save: 940
# Processing item number: 428
# Question count : 5
# Item count in the JSON file after save: 941
# Item count in the JSON file after save: 942
# Item count in the JSON file after save: 943
# Item count in the JSON file after save: 944
# Item count in the JSON file after save: 945
# Processing item number: 429
# Question count : 5
# Item count in the JSON file after save: 946
# Item count in the JSON file after save: 947
# Item count in the JSON file after save: 948
# Item count in the JSON file after save: 949
# Item count in the JSON file after save: 950
# Processing item number: 430
# Processing item number: 431
# Question count : 1
# Item count in the JSON file after save: 951
# Processing item number: 432
# Processing item number: 433
# Question count : 5
# Item count in the JSON file after save: 952
# Item count in the JSON file after save: 953
# Item count in the JSON file after save: 954
# Item count in the JSON file after save: 955
# Item count in the JSON file after save: 956
# Processing item number: 434
# Question count : 5
# Item count in the JSON file after save: 957
# Item count in the JSON file after save: 958
# Item count in the JSON file after save: 959
# Item count in the JSON file after save: 960
# Item count in the JSON file after save: 961
# Processing item number: 435
# Question count : 3
# Item count in the JSON file after save: 962
# Item count in the JSON file after save: 963
# Item count in the JSON file after save: 964
# Processing item number: 436
# Question count : 2
# Item count in the JSON file after save: 965
# Item count in the JSON file after save: 966
# Processing item number: 437
# Question count : 2
# Item count in the JSON file after save: 967
# Item count in the JSON file after save: 968
# Processing item number: 438
# Question count : 4
# Item count in the JSON file after save: 969
# Item count in the JSON file after save: 970
# Item count in the JSON file after save: 971
# Item count in the JSON file after save: 972
# Processing item number: 439
# Question count : 4
# Item count in the JSON file after save: 973
# Item count in the JSON file after save: 974
# Item count in the JSON file after save: 975
# Item count in the JSON file after save: 976
# Processing item number: 440
# Question count : 5
# Item count in the JSON file after save: 977
# Item count in the JSON file after save: 978
# Item count in the JSON file after save: 979
# Item count in the JSON file after save: 980
# Item count in the JSON file after save: 981
# Processing item number: 441
# Question count : 4
# Item count in the JSON file after save: 982
# Item count in the JSON file after save: 983
# Item count in the JSON file after save: 984
# Item count in the JSON file after save: 985
# Processing item number: 442
# Question count : 2
# Item count in the JSON file after save: 986
# Item count in the JSON file after save: 987
# Processing item number: 443
# Question count : 3
# Item count in the JSON file after save: 988
# Item count in the JSON file after save: 989
# Item count in the JSON file after save: 990
# Processing item number: 444
# Question count : 2
# Item count in the JSON file after save: 991
# Item count in the JSON file after save: 992
# Processing item number: 445
# Question count : 1
# Item count in the JSON file after save: 993
# Processing item number: 446
# Question count : 3
# Item count in the JSON file after save: 994
# Item count in the JSON file after save: 995
# Item count in the JSON file after save: 996
# Processing item number: 447
# Question count : 3
# Item count in the JSON file after save: 997
# Item count in the JSON file after save: 998
# Item count in the JSON file after save: 999
# Processing item number: 448
# Question count : 5
# Item count in the JSON file after save: 1000
# Item count in the JSON file after save: 1001
# Item count in the JSON file after save: 1002
# Item count in the JSON file after save: 1003
# Item count in the JSON file after save: 1004
# Processing item number: 449
# Processing item number: 450
# Processing item number: 451
# Question count : 5
# Item count in the JSON file after save: 1005
# Item count in the JSON file after save: 1006
# Item count in the JSON file after save: 1007
# Item count in the JSON file after save: 1008
# Item count in the JSON file after save: 1009
# Processing item number: 452
# Processing item number: 453
# Question count : 11
# Item count in the JSON file after save: 1010
# Item count in the JSON file after save: 1011
# Item count in the JSON file after save: 1012
# Item count in the JSON file after save: 1013
# Item count in the JSON file after save: 1014
# Item count in the JSON file after save: 1015
# Item count in the JSON file after save: 1016
# Item count in the JSON file after save: 1017
# Item count in the JSON file after save: 1018
# Item count in the JSON file after save: 1019
# Item count in the JSON file after save: 1020
# Processing item number: 454
# Processing item number: 455
# Question count : 5
# Item count in the JSON file after save: 1021
# Item count in the JSON file after save: 1022
# Item count in the JSON file after save: 1023
# Item count in the JSON file after save: 1024
# Item count in the JSON file after save: 1025
# Processing item number: 456
# Question count : 5
# Item count in the JSON file after save: 1026
# Item count in the JSON file after save: 1027
# Item count in the JSON file after save: 1028
# Item count in the JSON file after save: 1029
# Item count in the JSON file after save: 1030
# Processing item number: 457
# Question count : 5
# Item count in the JSON file after save: 1031
# Item count in the JSON file after save: 1032
# Item count in the JSON file after save: 1033
# Item count in the JSON file after save: 1034
# Item count in the JSON file after save: 1035
# Processing item number: 458
# Processing item number: 459
# Question count : 3
# Item count in the JSON file after save: 1036
# Item count in the JSON file after save: 1037
# Item count in the JSON file after save: 1038
# Processing item number: 460
# Processing item number: 461
# Question count : 5
# Item count in the JSON file after save: 1039
# Item count in the JSON file after save: 1040
# Item count in the JSON file after save: 1041
# Item count in the JSON file after save: 1042
# Item count in the JSON file after save: 1043
# Processing item number: 462
# Question count : 3
# Item count in the JSON file after save: 1044
# Item count in the JSON file after save: 1045
# Item count in the JSON file after save: 1046
# Processing item number: 463
# Question count : 3
# Item count in the JSON file after save: 1047
# Item count in the JSON file after save: 1048
# Item count in the JSON file after save: 1049
# Processing item number: 464
# Question count : 4
# Item count in the JSON file after save: 1050
# Item count in the JSON file after save: 1051
# Item count in the JSON file after save: 1052
# Item count in the JSON file after save: 1053
# Processing item number: 465
# Question count : 2
# Item count in the JSON file after save: 1054
# Item count in the JSON file after save: 1055
# Processing item number: 466
# Question count : 5
# Item count in the JSON file after save: 1056
# Item count in the JSON file after save: 1057
# Item count in the JSON file after save: 1058
# Item count in the JSON file after save: 1059
# Item count in the JSON file after save: 1060
# Processing item number: 467
# Processing item number: 468
# Question count : 3
# Item count in the JSON file after save: 1061
# Item count in the JSON file after save: 1062
# Item count in the JSON file after save: 1063
# Processing item number: 469
# Question count : 4
# Item count in the JSON file after save: 1064
# Item count in the JSON file after save: 1065
# Item count in the JSON file after save: 1066
# Item count in the JSON file after save: 1067
# Processing item number: 470
# Processing item number: 471
# Question count : 3
# Item count in the JSON file after save: 1068
# Item count in the JSON file after save: 1069
# Item count in the JSON file after save: 1070
# Processing item number: 472
# Question count : 1
# Item count in the JSON file after save: 1071
# Processing item number: 473
# Question count : 3
# Item count in the JSON file after save: 1072
# Item count in the JSON file after save: 1073
# Item count in the JSON file after save: 1074
# Processing item number: 474
# Question count : 3
# Item count in the JSON file after save: 1075
# Item count in the JSON file after save: 1076
# Item count in the JSON file after save: 1077
# Processing item number: 475
# Question count : 5
# Item count in the JSON file after save: 1078
# Item count in the JSON file after save: 1079
# Item count in the JSON file after save: 1080
# Item count in the JSON file after save: 1081
# Item count in the JSON file after save: 1082
# Processing item number: 476
# Question count : 1
# Item count in the JSON file after save: 1083
# Processing item number: 477
# Question count : 5
# Item count in the JSON file after save: 1084
# Item count in the JSON file after save: 1085
# Item count in the JSON file after save: 1086
# Item count in the JSON file after save: 1087
# Item count in the JSON file after save: 1088
# Processing item number: 478
# Question count : 3
# Item count in the JSON file after save: 1089
# Item count in the JSON file after save: 1090
# Item count in the JSON file after save: 1091
# Processing item number: 479
# Processing item number: 480
# Processing item number: 481
# Question count : 1
# Item count in the JSON file after save: 1092
# Processing item number: 482
# Question count : 4
# Item count in the JSON file after save: 1093
# Item count in the JSON file after save: 1094
# Item count in the JSON file after save: 1095
# Item count in the JSON file after save: 1096
# Processing item number: 483
# Question count : 1
# Item count in the JSON file after save: 1097
# Processing item number: 484
# Processing item number: 485
# Question count : 3
# Item count in the JSON file after save: 1098
# Item count in the JSON file after save: 1099
# Item count in the JSON file after save: 1100
# Processing item number: 486
# Question count : 4
# Item count in the JSON file after save: 1101
# Item count in the JSON file after save: 1102
# Item count in the JSON file after save: 1103
# Item count in the JSON file after save: 1104
# Processing item number: 487
# Processing item number: 488
# Question count : 4
# Item count in the JSON file after save: 1105
# Item count in the JSON file after save: 1106
# Item count in the JSON file after save: 1107
# Item count in the JSON file after save: 1108
# Processing item number: 489
# Question count : 2
# Item count in the JSON file after save: 1109
# Item count in the JSON file after save: 1110
# Processing item number: 490
# Question count : 5
# Item count in the JSON file after save: 1111
# Item count in the JSON file after save: 1112
# Item count in the JSON file after save: 1113
# Item count in the JSON file after save: 1114
# Item count in the JSON file after save: 1115
# Processing item number: 491
# Question count : 3
# Item count in the JSON file after save: 1116
# Item count in the JSON file after save: 1117
# Item count in the JSON file after save: 1118
# Processing item number: 492
# Question count : 1
# Item count in the JSON file after save: 1119
# Processing item number: 493
# Question count : 5
# Item count in the JSON file after save: 1120
# Item count in the JSON file after save: 1121
# Item count in the JSON file after save: 1122
# Item count in the JSON file after save: 1123
# Item count in the JSON file after save: 1124
# Processing item number: 494
# Question count : 3
# Item count in the JSON file after save: 1125
# Item count in the JSON file after save: 1126
# Item count in the JSON file after save: 1127
# Processing item number: 495
# Question count : 4
# Item count in the JSON file after save: 1128
# Item count in the JSON file after save: 1129
# Item count in the JSON file after save: 1130
# Item count in the JSON file after save: 1131
# Processing item number: 496
# Question count : 5
# Item count in the JSON file after save: 1132
# Item count in the JSON file after save: 1133
# Item count in the JSON file after save: 1134
# Item count in the JSON file after save: 1135
# Item count in the JSON file after save: 1136
# Processing item number: 497
# Question count : 5
# Item count in the JSON file after save: 1137
# Item count in the JSON file after save: 1138
# Item count in the JSON file after save: 1139
# Item count in the JSON file after save: 1140
# Item count in the JSON file after save: 1141
# Processing item number: 498
# Processing item number: 499
# Question count : 3
# Item count in the JSON file after save: 1142
# Item count in the JSON file after save: 1143
# Item count in the JSON file after save: 1144
# Processing item number: 500
# Question count : 4
# Item count in the JSON file after save: 1145
# Item count in the JSON file after save: 1146
# Item count in the JSON file after save: 1147
# Item count in the JSON file after save: 1148
# Processing item number: 501
# Processing item number: 502
# Question count : 5
# Item count in the JSON file after save: 1149
# Item count in the JSON file after save: 1150
# Item count in the JSON file after save: 1151
# Item count in the JSON file after save: 1152
# Item count in the JSON file after save: 1153
# Processing item number: 503
# Question count : 1
# Item count in the JSON file after save: 1154
# Processing item number: 504
# Question count : 1
# Item count in the JSON file after save: 1155
# Processing item number: 505
# Processing item number: 506
# Question count : 5
# Item count in the JSON file after save: 1156
# Item count in the JSON file after save: 1157
# Item count in the JSON file after save: 1158
# Item count in the JSON file after save: 1159
# Item count in the JSON file after save: 1160
# Processing item number: 507
# Question count : 3
# Item count in the JSON file after save: 1161
# Item count in the JSON file after save: 1162
# Item count in the JSON file after save: 1163
# Processing item number: 508
# Question count : 5
# Item count in the JSON file after save: 1164
# Item count in the JSON file after save: 1165
# Item count in the JSON file after save: 1166
# Item count in the JSON file after save: 1167
# Item count in the JSON file after save: 1168
# Processing item number: 509
# Question count : 3
# Item count in the JSON file after save: 1169
# Item count in the JSON file after save: 1170
# Item count in the JSON file after save: 1171
# Processing item number: 510
# Question count : 3
# Item count in the JSON file after save: 1172
# Item count in the JSON file after save: 1173
# Item count in the JSON file after save: 1174
# Processing item number: 511
# Question count : 5
# Item count in the JSON file after save: 1175
# Item count in the JSON file after save: 1176
# Item count in the JSON file after save: 1177
# Item count in the JSON file after save: 1178
# Item count in the JSON file after save: 1179
# Processing item number: 512
# Question count : 3
# Item count in the JSON file after save: 1180
# Item count in the JSON file after save: 1181
# Item count in the JSON file after save: 1182
# Processing item number: 513
# Processing item number: 514
# Question count : 4
# Item count in the JSON file after save: 1183
# Item count in the JSON file after save: 1184
# Item count in the JSON file after save: 1185
# Item count in the JSON file after save: 1186
# Processing item number: 515
# Processing item number: 516
# Question count : 5
# Item count in the JSON file after save: 1187
# Item count in the JSON file after save: 1188
# Item count in the JSON file after save: 1189
# Item count in the JSON file after save: 1190
# Item count in the JSON file after save: 1191
# Processing item number: 517
# Question count : 5
# Item count in the JSON file after save: 1192
# Item count in the JSON file after save: 1193
# Item count in the JSON file after save: 1194
# Item count in the JSON file after save: 1195
# Item count in the JSON file after save: 1196
# Processing item number: 518
# Question count : 4
# Item count in the JSON file after save: 1197
# Item count in the JSON file after save: 1198
# Item count in the JSON file after save: 1199
# Item count in the JSON file after save: 1200
# Processing item number: 519
# Question count : 5
# Item count in the JSON file after save: 1201
# Item count in the JSON file after save: 1202
# Item count in the JSON file after save: 1203
# Item count in the JSON file after save: 1204
# Item count in the JSON file after save: 1205
# Processing item number: 520
# Question count : 3
# Item count in the JSON file after save: 1206
# Item count in the JSON file after save: 1207
# Item count in the JSON file after save: 1208
# Processing item number: 521
# Processing item number: 522
# Question count : 1
# Item count in the JSON file after save: 1209
# Processing item number: 523
# Question count : 5
# Item count in the JSON file after save: 1210
# Item count in the JSON file after save: 1211
# Item count in the JSON file after save: 1212
# Item count in the JSON file after save: 1213
# Item count in the JSON file after save: 1214
# Processing item number: 524
# Question count : 5
# Item count in the JSON file after save: 1215
# Item count in the JSON file after save: 1216
# Item count in the JSON file after save: 1217
# Item count in the JSON file after save: 1218
# Item count in the JSON file after save: 1219
# Processing item number: 525
# Question count : 2
# Item count in the JSON file after save: 1220
# Item count in the JSON file after save: 1221
# Processing item number: 526
# Question count : 5
# Item count in the JSON file after save: 1222
# Item count in the JSON file after save: 1223
# Item count in the JSON file after save: 1224
# Item count in the JSON file after save: 1225
# Item count in the JSON file after save: 1226
# Processing item number: 527
# Question count : 4
# Item count in the JSON file after save: 1227
# Item count in the JSON file after save: 1228
# Item count in the JSON file after save: 1229
# Item count in the JSON file after save: 1230
# Processing item number: 528
# Question count : 1
# Item count in the JSON file after save: 1231
# Processing item number: 529
# Question count : 4
# Item count in the JSON file after save: 1232
# Item count in the JSON file after save: 1233
# Item count in the JSON file after save: 1234
# Item count in the JSON file after save: 1235
# Processing item number: 530
# Processing item number: 531
# Question count : 3
# Item count in the JSON file after save: 1236
# Item count in the JSON file after save: 1237
# Item count in the JSON file after save: 1238
# Processing item number: 532
# Question count : 5
# Item count in the JSON file after save: 1239
# Item count in the JSON file after save: 1240
# Item count in the JSON file after save: 1241
# Item count in the JSON file after save: 1242
# Item count in the JSON file after save: 1243
# Processing item number: 533
# Question count : 3
# Item count in the JSON file after save: 1244
# Item count in the JSON file after save: 1245
# Item count in the JSON file after save: 1246
# Processing item number: 534
# Question count : 3
# Item count in the JSON file after save: 1247
# Item count in the JSON file after save: 1248
# Item count in the JSON file after save: 1249
# Processing item number: 535
# Question count : 5
# Item count in the JSON file after save: 1250
# Item count in the JSON file after save: 1251
# Item count in the JSON file after save: 1252
# Item count in the JSON file after save: 1253
# Item count in the JSON file after save: 1254
# Processing item number: 536
# Question count : 3
# Item count in the JSON file after save: 1255
# Item count in the JSON file after save: 1256
# Item count in the JSON file after save: 1257
# Processing item number: 537
# Question count : 3
# Item count in the JSON file after save: 1258
# Item count in the JSON file after save: 1259
# Item count in the JSON file after save: 1260
# Processing item number: 538
# Question count : 3
# Item count in the JSON file after save: 1261
# Item count in the JSON file after save: 1262
# Item count in the JSON file after save: 1263
# Processing item number: 539
# Question count : 5
# Item count in the JSON file after save: 1264
# Item count in the JSON file after save: 1265
# Item count in the JSON file after save: 1266
# Item count in the JSON file after save: 1267
# Item count in the JSON file after save: 1268
# Processing item number: 540
# Processing item number: 541
# Question count : 5
# Item count in the JSON file after save: 1269
# Item count in the JSON file after save: 1270
# Item count in the JSON file after save: 1271
# Item count in the JSON file after save: 1272
# Item count in the JSON file after save: 1273
# Processing item number: 542
# Question count : 5
# Item count in the JSON file after save: 1274
# Item count in the JSON file after save: 1275
# Item count in the JSON file after save: 1276
# Item count in the JSON file after save: 1277
# Item count in the JSON file after save: 1278
# Processing item number: 543
# Question count : 3
# Item count in the JSON file after save: 1279
# Item count in the JSON file after save: 1280
# Item count in the JSON file after save: 1281
# Processing item number: 544
# Question count : 5
# Item count in the JSON file after save: 1282
# Item count in the JSON file after save: 1283
# Item count in the JSON file after save: 1284
# Item count in the JSON file after save: 1285
# Item count in the JSON file after save: 1286
# Processing item number: 545
# Question count : 5
# Item count in the JSON file after save: 1287
# Item count in the JSON file after save: 1288
# Item count in the JSON file after save: 1289
# Item count in the JSON file after save: 1290
# Item count in the JSON file after save: 1291
# Processing item number: 546
# Question count : 2
# Item count in the JSON file after save: 1292
# Item count in the JSON file after save: 1293
# Processing item number: 547
# Question count : 3
# Item count in the JSON file after save: 1294
# Item count in the JSON file after save: 1295
# Item count in the JSON file after save: 1296
# Processing item number: 548
# Question count : 5
# Item count in the JSON file after save: 1297
# Item count in the JSON file after save: 1298
# Item count in the JSON file after save: 1299
# Item count in the JSON file after save: 1300
# Item count in the JSON file after save: 1301
# Processing item number: 549
# Question count : 4
# Item count in the JSON file after save: 1302
# Item count in the JSON file after save: 1303
# Item count in the JSON file after save: 1304
# Item count in the JSON file after save: 1305
# Processing item number: 550
# Question count : 3
# Item count in the JSON file after save: 1306
# Item count in the JSON file after save: 1307
# Item count in the JSON file after save: 1308
# Processing item number: 551
# Question count : 1
# Item count in the JSON file after save: 1309
# Processing item number: 552
# Question count : 5
# Item count in the JSON file after save: 1310
# Item count in the JSON file after save: 1311
# Item count in the JSON file after save: 1312
# Item count in the JSON file after save: 1313
# Item count in the JSON file after save: 1314
# Processing item number: 553
# Processing item number: 554
# Question count : 4
# Item count in the JSON file after save: 1315
# Item count in the JSON file after save: 1316
# Item count in the JSON file after save: 1317
# Item count in the JSON file after save: 1318
# Processing item number: 555
# Question count : 2
# Item count in the JSON file after save: 1319
# Item count in the JSON file after save: 1320
# Processing item number: 556
# Question count : 2
# Item count in the JSON file after save: 1321
# Item count in the JSON file after save: 1322
# Processing item number: 557
# Question count : 3
# Item count in the JSON file after save: 1323
# Item count in the JSON file after save: 1324
# Item count in the JSON file after save: 1325
# Processing item number: 558
# Question count : 5
# Item count in the JSON file after save: 1326
# Item count in the JSON file after save: 1327
# Item count in the JSON file after save: 1328
# Item count in the JSON file after save: 1329
# Item count in the JSON file after save: 1330
# Processing item number: 559
# Question count : 5
# Item count in the JSON file after save: 1331
# Item count in the JSON file after save: 1332
# Item count in the JSON file after save: 1333
# Item count in the JSON file after save: 1334
# Item count in the JSON file after save: 1335
# Processing item number: 560
# Question count : 3
# Item count in the JSON file after save: 1336
# Item count in the JSON file after save: 1337
# Item count in the JSON file after save: 1338
# Processing item number: 561
# Question count : 5
# Item count in the JSON file after save: 1339
# Item count in the JSON file after save: 1340
# Item count in the JSON file after save: 1341
# Item count in the JSON file after save: 1342
# Item count in the JSON file after save: 1343
# Processing item number: 562
# Processing item number: 563
# Question count : 3
# Item count in the JSON file after save: 1344
# Item count in the JSON file after save: 1345
# Item count in the JSON file after save: 1346
# Processing item number: 564
# Question count : 1
# Item count in the JSON file after save: 1347
# Processing item number: 565
# Question count : 3
# Item count in the JSON file after save: 1348
# Item count in the JSON file after save: 1349
# Item count in the JSON file after save: 1350
# Processing item number: 566
# Question count : 5
# Item count in the JSON file after save: 1351
# Item count in the JSON file after save: 1352
# Item count in the JSON file after save: 1353
# Item count in the JSON file after save: 1354
# Item count in the JSON file after save: 1355
# Processing item number: 567
# Question count : 2
# Item count in the JSON file after save: 1356
# Item count in the JSON file after save: 1357
# Processing item number: 568
# Question count : 3
# Item count in the JSON file after save: 1358
# Item count in the JSON file after save: 1359
# Item count in the JSON file after save: 1360
# Processing item number: 569
# Question count : 1
# Item count in the JSON file after save: 1361
# Processing item number: 570
# Question count : 5
# Item count in the JSON file after save: 1362
# Item count in the JSON file after save: 1363
# Item count in the JSON file after save: 1364
# Item count in the JSON file after save: 1365
# Item count in the JSON file after save: 1366
# Processing item number: 571
# Question count : 2
# Item count in the JSON file after save: 1367
# Item count in the JSON file after save: 1368
# Processing item number: 572
# Question count : 1
# Item count in the JSON file after save: 1369
# Processing item number: 573
# Question count : 3
# Item count in the JSON file after save: 1370
# Item count in the JSON file after save: 1371
# Item count in the JSON file after save: 1372
# Processing item number: 574
# Processing item number: 575
# Question count : 4
# Item count in the JSON file after save: 1373
# Item count in the JSON file after save: 1374
# Item count in the JSON file after save: 1375
# Item count in the JSON file after save: 1376
# Processing item number: 576
# Question count : 3
# Item count in the JSON file after save: 1377
# Item count in the JSON file after save: 1378
# Item count in the JSON file after save: 1379
# Processing item number: 577
# Question count : 5
# Item count in the JSON file after save: 1380
# Item count in the JSON file after save: 1381
# Item count in the JSON file after save: 1382
# Item count in the JSON file after save: 1383
# Item count in the JSON file after save: 1384
# Processing item number: 578
# Processing item number: 579
# Question count : 5
# Item count in the JSON file after save: 1385
# Item count in the JSON file after save: 1386
# Item count in the JSON file after save: 1387
# Item count in the JSON file after save: 1388
# Item count in the JSON file after save: 1389
# Processing item number: 580
# Processing item number: 581
# Question count : 5
# Item count in the JSON file after save: 1390
# Item count in the JSON file after save: 1391
# Item count in the JSON file after save: 1392
# Item count in the JSON file after save: 1393
# Item count in the JSON file after save: 1394
# Processing item number: 582
# Question count : 3
# Item count in the JSON file after save: 1395
# Item count in the JSON file after save: 1396
# Item count in the JSON file after save: 1397
# Processing item number: 583
# Question count : 3
# Item count in the JSON file after save: 1398
# Item count in the JSON file after save: 1399
# Item count in the JSON file after save: 1400
# Processing item number: 584
# Question count : 2
# Item count in the JSON file after save: 1401
# Item count in the JSON file after save: 1402
# Processing item number: 585
# Processing item number: 586
# Processing item number: 587
# Question count : 4
# Item count in the JSON file after save: 1403
# Item count in the JSON file after save: 1404
# Item count in the JSON file after save: 1405
# Item count in the JSON file after save: 1406
# Processing item number: 588
# Question count : 2
# Item count in the JSON file after save: 1407
# Item count in the JSON file after save: 1408
# Processing item number: 589
# Question count : 5
# Item count in the JSON file after save: 1409
# Item count in the JSON file after save: 1410
# Item count in the JSON file after save: 1411
# Item count in the JSON file after save: 1412
# Item count in the JSON file after save: 1413
# Processing item number: 590
# Processing item number: 591
# Processing item number: 592
# Question count : 3
# Item count in the JSON file after save: 1414
# Item count in the JSON file after save: 1415
# Item count in the JSON file after save: 1416
# Processing item number: 593
# Question count : 3
# Item count in the JSON file after save: 1417
# Item count in the JSON file after save: 1418
# Item count in the JSON file after save: 1419
# Processing item number: 594
# Question count : 4
# Item count in the JSON file after save: 1420
# Item count in the JSON file after save: 1421
# Item count in the JSON file after save: 1422
# Item count in the JSON file after save: 1423
# Processing item number: 595
# Processing item number: 596
# Question count : 5
# Item count in the JSON file after save: 1424
# Item count in the JSON file after save: 1425
# Item count in the JSON file after save: 1426
# Item count in the JSON file after save: 1427
# Item count in the JSON file after save: 1428
# Processing item number: 597
# Question count : 3
# Item count in the JSON file after save: 1429
# Item count in the JSON file after save: 1430
# Item count in the JSON file after save: 1431
# Processing item number: 598
# Processing item number: 599
# Processing item number: 600
# Question count : 5
# Item count in the JSON file after save: 1432
# Item count in the JSON file after save: 1433
# Item count in the JSON file after save: 1434
# Item count in the JSON file after save: 1435
# Item count in the JSON file after save: 1436
# Processing item number: 601
# Question count : 7
# Item count in the JSON file after save: 1437
# Item count in the JSON file after save: 1438
# Item count in the JSON file after save: 1439
# Item count in the JSON file after save: 1440
# Item count in the JSON file after save: 1441
# Item count in the JSON file after save: 1442
# Item count in the JSON file after save: 1443
# Processing item number: 602
# Question count : 2
# Item count in the JSON file after save: 1444
# Item count in the JSON file after save: 1445
# Processing item number: 603
# Processing item number: 604
# Question count : 10
# Item count in the JSON file after save: 1446
# Item count in the JSON file after save: 1447
# Item count in the JSON file after save: 1448
# Item count in the JSON file after save: 1449
# Item count in the JSON file after save: 1450
# Item count in the JSON file after save: 1451
# Item count in the JSON file after save: 1452
# Item count in the JSON file after save: 1453
# Item count in the JSON file after save: 1454
# Item count in the JSON file after save: 1455
# Processing item number: 605
# Question count : 3
# Item count in the JSON file after save: 1456
# Item count in the JSON file after save: 1457
# Item count in the JSON file after save: 1458
# Processing item number: 606
# Question count : 5
# Item count in the JSON file after save: 1459
# Item count in the JSON file after save: 1460
# Item count in the JSON file after save: 1461
# Item count in the JSON file after save: 1462
# Item count in the JSON file after save: 1463
# Processing item number: 607
# Processing item number: 608
# Processing item number: 609
# Question count : 3
# Item count in the JSON file after save: 1464
# Item count in the JSON file after save: 1465
# Item count in the JSON file after save: 1466
# Processing item number: 610
# Processing item number: 611
# Question count : 3
# Item count in the JSON file after save: 1467
# Item count in the JSON file after save: 1468
# Item count in the JSON file after save: 1469
# Processing item number: 612
# Question count : 2
# Item count in the JSON file after save: 1470
# Item count in the JSON file after save: 1471
# Processing item number: 613
# Question count : 7
# Item count in the JSON file after save: 1472
# Item count in the JSON file after save: 1473
# Item count in the JSON file after save: 1474
# Item count in the JSON file after save: 1475
# Item count in the JSON file after save: 1476
# Item count in the JSON file after save: 1477
# Item count in the JSON file after save: 1478
# Processing item number: 614
# Question count : 4
# Item count in the JSON file after save: 1479
# Item count in the JSON file after save: 1480
# Item count in the JSON file after save: 1481
# Item count in the JSON file after save: 1482
# Processing item number: 615
# Processing item number: 616
# Processing item number: 617
# Processing item number: 618
# Question count : 5
# Item count in the JSON file after save: 1483
# Item count in the JSON file after save: 1484
# Item count in the JSON file after save: 1485
# Item count in the JSON file after save: 1486
# Item count in the JSON file after save: 1487
# Processing item number: 619
# Question count : 1
# Item count in the JSON file after save: 1488
# Processing item number: 620
# Question count : 7
# Item count in the JSON file after save: 1489
# Item count in the JSON file after save: 1490
# Item count in the JSON file after save: 1491
# Item count in the JSON file after save: 1492
# Item count in the JSON file after save: 1493
# Item count in the JSON file after save: 1494
# Item count in the JSON file after save: 1495
# Processing item number: 621
# Question count : 5
# Item count in the JSON file after save: 1496
# Item count in the JSON file after save: 1497
# Item count in the JSON file after save: 1498
# Item count in the JSON file after save: 1499
# Item count in the JSON file after save: 1500
# Processing item number: 622
# Processing item number: 623
# Processing item number: 624
# Question count : 1
# Item count in the JSON file after save: 1501
# Processing item number: 625
# Question count : 3
# Item count in the JSON file after save: 1502
# Item count in the JSON file after save: 1503
# Item count in the JSON file after save: 1504
# Processing item number: 626
# Question count : 3
# Item count in the JSON file after save: 1505
# Item count in the JSON file after save: 1506
# Item count in the JSON file after save: 1507
# Processing item number: 627
# Processing item number: 628
# Question count : 1
# Item count in the JSON file after save: 1508
# Processing item number: 629
# Question count : 5
# Item count in the JSON file after save: 1509
# Item count in the JSON file after save: 1510
# Item count in the JSON file after save: 1511
# Item count in the JSON file after save: 1512
# Item count in the JSON file after save: 1513
# Processing item number: 630
# Question count : 1
# Item count in the JSON file after save: 1514
# Processing item number: 631
# Question count : 4
# Item count in the JSON file after save: 1515
# Item count in the JSON file after save: 1516
# Item count in the JSON file after save: 1517
# Item count in the JSON file after save: 1518
# Processing item number: 632
# Question count : 3
# Item count in the JSON file after save: 1519
# Item count in the JSON file after save: 1520
# Item count in the JSON file after save: 1521
# Processing item number: 633
# Processing item number: 634
# Question count : 3
# Item count in the JSON file after save: 1522
# Item count in the JSON file after save: 1523
# Item count in the JSON file after save: 1524
# Processing item number: 635
# Question count : 3
# Item count in the JSON file after save: 1525
# Item count in the JSON file after save: 1526
# Item count in the JSON file after save: 1527
# Processing item number: 636
# Question count : 5
# Item count in the JSON file after save: 1528
# Item count in the JSON file after save: 1529
# Item count in the JSON file after save: 1530
# Item count in the JSON file after save: 1531
# Item count in the JSON file after save: 1532
# Processing item number: 637
# Processing item number: 638
# Question count : 2
# Item count in the JSON file after save: 1533
# Item count in the JSON file after save: 1534
# Processing item number: 639
# Question count : 5
# Item count in the JSON file after save: 1535
# Item count in the JSON file after save: 1536
# Item count in the JSON file after save: 1537
# Item count in the JSON file after save: 1538
# Item count in the JSON file after save: 1539
# Processing item number: 640
# Processing item number: 641
# Question count : 5
# Item count in the JSON file after save: 1540
# Item count in the JSON file after save: 1541
# Item count in the JSON file after save: 1542
# Item count in the JSON file after save: 1543
# Item count in the JSON file after save: 1544
# Processing item number: 642
# Question count : 5
# Item count in the JSON file after save: 1545
# Item count in the JSON file after save: 1546
# Item count in the JSON file after save: 1547
# Item count in the JSON file after save: 1548
# Item count in the JSON file after save: 1549
# Processing item number: 643
# Processing item number: 644
# Question count : 5
# Item count in the JSON file after save: 1550
# Item count in the JSON file after save: 1551
# Item count in the JSON file after save: 1552
# Item count in the JSON file after save: 1553
# Item count in the JSON file after save: 1554
# Processing item number: 645
# Question count : 2
# Item count in the JSON file after save: 1555
# Item count in the JSON file after save: 1556
# Processing item number: 646
# Processing item number: 647
# Question count : 1
# Item count in the JSON file after save: 1557
# Processing item number: 648
# Question count : 4
# Item count in the JSON file after save: 1558
# Item count in the JSON file after save: 1559
# Item count in the JSON file after save: 1560
# Item count in the JSON file after save: 1561
# Processing item number: 649
# Question count : 3
# Item count in the JSON file after save: 1562
# Item count in the JSON file after save: 1563
# Item count in the JSON file after save: 1564
# Processing item number: 650
# Question count : 1
# Item count in the JSON file after save: 1565
# Processing item number: 651
# Question count : 4
# Item count in the JSON file after save: 1566
# Item count in the JSON file after save: 1567
# Item count in the JSON file after save: 1568
# Item count in the JSON file after save: 1569
# Processing item number: 652
# Question count : 3
# Item count in the JSON file after save: 1570
# Item count in the JSON file after save: 1571
# Item count in the JSON file after save: 1572
# Processing item number: 653
# Processing item number: 654
# Question count : 2
# Item count in the JSON file after save: 1573
# Item count in the JSON file after save: 1574
# Processing item number: 655
# Question count : 3
# Item count in the JSON file after save: 1575
# Item count in the JSON file after save: 1576
# Item count in the JSON file after save: 1577
# Processing item number: 656
# Question count : 5
# Item count in the JSON file after save: 1578
# Item count in the JSON file after save: 1579
# Item count in the JSON file after save: 1580
# Item count in the JSON file after save: 1581
# Item count in the JSON file after save: 1582
# Processing item number: 657
# Question count : 5
# Item count in the JSON file after save: 1583
# Item count in the JSON file after save: 1584
# Item count in the JSON file after save: 1585
# Item count in the JSON file after save: 1586
# Item count in the JSON file after save: 1587
# Processing item number: 658
# Question count : 5
# Item count in the JSON file after save: 1588
# Item count in the JSON file after save: 1589
# Item count in the JSON file after save: 1590
# Item count in the JSON file after save: 1591
# Item count in the JSON file after save: 1592
# Processing item number: 659
# Processing item number: 660
# Question count : 5
# Item count in the JSON file after save: 1593
# Item count in the JSON file after save: 1594
# Item count in the JSON file after save: 1595
# Item count in the JSON file after save: 1596
# Item count in the JSON file after save: 1597
# Processing item number: 661
# Question count : 5
# Item count in the JSON file after save: 1598
# Item count in the JSON file after save: 1599
# Item count in the JSON file after save: 1600
# Item count in the JSON file after save: 1601
# Item count in the JSON file after save: 1602
# Processing item number: 662
# Question count : 3
# Item count in the JSON file after save: 1603
# Item count in the JSON file after save: 1604
# Item count in the JSON file after save: 1605
# Processing item number: 663
# Question count : 1
# Item count in the JSON file after save: 1606
# Processing item number: 664
# Question count : 3
# Item count in the JSON file after save: 1607
# Item count in the JSON file after save: 1608
# Item count in the JSON file after save: 1609
# Processing item number: 665
# Processing item number: 666
# Question count : 1
# Item count in the JSON file after save: 1610
# Processing item number: 667
# Question count : 3
# Item count in the JSON file after save: 1611
# Item count in the JSON file after save: 1612
# Item count in the JSON file after save: 1613
# Processing item number: 668
# Processing item number: 669
# Question count : 2
# Item count in the JSON file after save: 1614
# Item count in the JSON file after save: 1615
# Processing item number: 670
# Question count : 5
# Item count in the JSON file after save: 1616
# Item count in the JSON file after save: 1617
# Item count in the JSON file after save: 1618
# Item count in the JSON file after save: 1619
# Item count in the JSON file after save: 1620
# Processing item number: 671
# Question count : 2
# Item count in the JSON file after save: 1621
# Item count in the JSON file after save: 1622
# Processing item number: 672
# Processing item number: 673
# Question count : 5
# Item count in the JSON file after save: 1623
# Item count in the JSON file after save: 1624
# Item count in the JSON file after save: 1625
# Item count in the JSON file after save: 1626
# Item count in the JSON file after save: 1627
# Processing item number: 674
# Question count : 1
# Item count in the JSON file after save: 1628
# Processing item number: 675
# Question count : 3
# Item count in the JSON file after save: 1629
# Item count in the JSON file after save: 1630
# Item count in the JSON file after save: 1631
# Processing item number: 676
# Question count : 5
# Item count in the JSON file after save: 1632
# Item count in the JSON file after save: 1633
# Item count in the JSON file after save: 1634
# Item count in the JSON file after save: 1635
# Item count in the JSON file after save: 1636
# Processing item number: 677
# Question count : 1
# Item count in the JSON file after save: 1637
# Processing item number: 678
# Question count : 5
# Item count in the JSON file after save: 1638
# Item count in the JSON file after save: 1639
# Item count in the JSON file after save: 1640
# Item count in the JSON file after save: 1641
# Item count in the JSON file after save: 1642
# Processing item number: 679
# Question count : 3
# Item count in the JSON file after save: 1643
# Item count in the JSON file after save: 1644
# Item count in the JSON file after save: 1645
# Processing item number: 680
# Processing item number: 681
# Question count : 7
# Item count in the JSON file after save: 1646
# Item count in the JSON file after save: 1647
# Item count in the JSON file after save: 1648
# Item count in the JSON file after save: 1649
# Item count in the JSON file after save: 1650
# Item count in the JSON file after save: 1651
# Item count in the JSON file after save: 1652
# Processing item number: 682
# Processing item number: 683
# Question count : 4
# Item count in the JSON file after save: 1653
# Item count in the JSON file after save: 1654
# Item count in the JSON file after save: 1655
# Item count in the JSON file after save: 1656
# Processing item number: 684
# Question count : 7
# Item count in the JSON file after save: 1657
# Item count in the JSON file after save: 1658
# Item count in the JSON file after save: 1659
# Item count in the JSON file after save: 1660
# Item count in the JSON file after save: 1661
# Item count in the JSON file after save: 1662
# Item count in the JSON file after save: 1663
# Processing item number: 685
# Question count : 1
# Item count in the JSON file after save: 1664
# Processing item number: 686
# Question count : 3
# Item count in the JSON file after save: 1665
# ...
# Item count in the JSON file after save: 2998
# Item count in the JSON file after save: 2999
# Processing item number: 1197
# Question count : 1
# Item count in the JSON file after save: 3000
# Processing item number: 1198
# Question count : 3
# Item count in the JSON file after save: 3001
# Item count in the JSON file after save: 3002
# Item count in the JSON file after save: 3003
# Processing item number: 1199
# Processing item number: 1200
# Question count : 5
# Item count in the JSON file after save: 3004
# Item count in the JSON file after save: 3005
# Item count in the JSON file after save: 3006
# Item count in the JSON file after save: 3007
# Item count in the JSON file after save: 3008
# Processing item number: 1201
# Question count : 4
# Item count in the JSON file after save: 3009
# Item count in the JSON file after save: 3010
# Item count in the JSON file after save: 3011
# Item count in the JSON file after save: 3012
# Processing item number: 1202
# Question count : 3
# Item count in the JSON file after save: 3013
# Item count in the JSON file after save: 3014
# Item count in the JSON file after save: 3015
# Processing item number: 1203
# Question count : 3
# Item count in the JSON file after save: 3016
# Item count in the JSON file after save: 3017
# Item count in the JSON file after save: 3018
# Processing item number: 1204
# Processing item number: 1205
# Processing item number: 1206
# Question count : 5
# Item count in the JSON file after save: 3019
# Item count in the JSON file after save: 3020
# Item count in the JSON file after save: 3021
# Item count in the JSON file after save: 3022
# Item count in the JSON file after save: 3023
# Processing item number: 1207
# Question count : 4
# Item count in the JSON file after save: 3024
# Item count in the JSON file after save: 3025
# Item count in the JSON file after save: 3026
# Item count in the JSON file after save: 3027
# Processing item number: 1208
# Processing item number: 1209
# Question count : 1
# Item count in the JSON file after save: 3028
# Processing item number: 1210
# Question count : 5
# Item count in the JSON file after save: 3029
# Item count in the JSON file after save: 3030
# Item count in the JSON file after save: 3031
# Item count in the JSON file after save: 3032
# Item count in the JSON file after save: 3033
# Processing item number: 1211
# Question count : 3
# Item count in the JSON file after save: 3034
# Item count in the JSON file after save: 3035
# Item count in the JSON file after save: 3036
# Processing item number: 1212
# Processing item number: 1213
# Question count : 3
# Item count in the JSON file after save: 3037
# Item count in the JSON file after save: 3038
# Item count in the JSON file after save: 3039
# Processing item number: 1214
# Question count : 2
# Item count in the JSON file after save: 3040
# Item count in the JSON file after save: 3041
# Processing item number: 1215
# Processing item number: 1216
# Question count : 3
# Item count in the JSON file after save: 3042
# Item count in the JSON file after save: 3043
# Item count in the JSON file after save: 3044
# Processing item number: 1217
# Question count : 7
# Item count in the JSON file after save: 3045
# Item count in the JSON file after save: 3046
# Item count in the JSON file after save: 3047
# Item count in the JSON file after save: 3048
# Item count in the JSON file after save: 3049
# Item count in the JSON file after save: 3050
# Item count in the JSON file after save: 3051
# Processing item number: 1218
# Question count : 6
# Item count in the JSON file after save: 3052
# Item count in the JSON file after save: 3053
# Item count in the JSON file after save: 3054
# Item count in the JSON file after save: 3055
# Item count in the JSON file after save: 3056
# Item count in the JSON file after save: 3057
# Processing item number: 1219
# Question count : 7
# Item count in the JSON file after save: 3058
# Item count in the JSON file after save: 3059
# Item count in the JSON file after save: 3060
# Item count in the JSON file after save: 3061
# Item count in the JSON file after save: 3062
# Item count in the JSON file after save: 3063
# Item count in the JSON file after save: 3064
# Processing item number: 1220
# Question count : 5
# Item count in the JSON file after save: 3065
# Item count in the JSON file after save: 3066
# Item count in the JSON file after save: 3067
# Item count in the JSON file after save: 3068
# Item count in the JSON file after save: 3069
# Processing item number: 1221
# Question count : 2
# Item count in the JSON file after save: 3070
# Item count in the JSON file after save: 3071
# Processing item number: 1222
# Processing item number: 1223
# Question count : 1
# Item count in the JSON file after save: 3072
# Processing item number: 1224
# Processing item number: 1225
# Question count : 4
# Item count in the JSON file after save: 3073
# Item count in the JSON file after save: 3074
# Item count in the JSON file after save: 3075
# Item count in the JSON file after save: 3076
# Processing item number: 1226
# Question count : 5
# Item count in the JSON file after save: 3077
# Item count in the JSON file after save: 3078
# Item count in the JSON file after save: 3079
# Item count in the JSON file after save: 3080
# Item count in the JSON file after save: 3081
# Processing item number: 1227
# Question count : 3
# Item count in the JSON file after save: 3082
# Item count in the JSON file after save: 3083
# Item count in the JSON file after save: 3084
# Processing item number: 1228
# Question count : 3
# Item count in the JSON file after save: 3085
# Item count in the JSON file after save: 3086
# Item count in the JSON file after save: 3087
# Processing item number: 1229
# Question count : 3
# Item count in the JSON file after save: 3088
# Item count in the JSON file after save: 3089
# Item count in the JSON file after save: 3090
# Processing item number: 1230
# Question count : 3
# Item count in the JSON file after save: 3091
# Item count in the JSON file after save: 3092
# Item count in the JSON file after save: 3093
# Processing item number: 1231
# Question count : 2
# Item count in the JSON file after save: 3094
# Item count in the JSON file after save: 3095
# Processing item number: 1232
# Question count : 2
# Item count in the JSON file after save: 3096
# Item count in the JSON file after save: 3097
# Processing item number: 1233
# Question count : 5
# Item count in the JSON file after save: 3098
# Item count in the JSON file after save: 3099
# Item count in the JSON file after save: 3100
# Item count in the JSON file after save: 3101
# Item count in the JSON file after save: 3102
# Processing item number: 1234
# Question count : 3
# Item count in the JSON file after save: 3103
# Item count in the JSON file after save: 3104
# Item count in the JSON file after save: 3105
# Processing item number: 1235
# Question count : 2
# Item count in the JSON file after save: 3106
# Item count in the JSON file after save: 3107
# Processing item number: 1236
# Question count : 2
# Item count in the JSON file after save: 3108
# Item count in the JSON file after save: 3109
# Processing item number: 1237
# Processing item number: 1238
# Question count : 3
# Item count in the JSON file after save: 3110
# Item count in the JSON file after save: 3111
# Item count in the JSON file after save: 3112
# Processing item number: 1239
# Question count : 5
# Item count in the JSON file after save: 3113
# Item count in the JSON file after save: 3114
# Item count in the JSON file after save: 3115
# Item count in the JSON file after save: 3116
# Item count in the JSON file after save: 3117
# Processing item number: 1240
# Question count : 9
# Item count in the JSON file after save: 3118
# Item count in the JSON file after save: 3119
# Item count in the JSON file after save: 3120
# Item count in the JSON file after save: 3121
# Item count in the JSON file after save: 3122
# Item count in the JSON file after save: 3123
# Item count in the JSON file after save: 3124
# Item count in the JSON file after save: 3125
# Item count in the JSON file after save: 3126
# Processing item number: 1241
# Processing item number: 1242
# Question count : 1
# Item count in the JSON file after save: 3127
# Processing item number: 1243
# Processing item number: 1244
# Question count : 4
# Item count in the JSON file after save: 3128
# Item count in the JSON file after save: 3129
# Item count in the JSON file after save: 3130
# Item count in the JSON file after save: 3131
# Processing item number: 1245
# Processing item number: 1246
# Question count : 2
# Item count in the JSON file after save: 3132
# Item count in the JSON file after save: 3133
# Processing item number: 1247
# Question count : 6
# Item count in the JSON file after save: 3134
# Item count in the JSON file after save: 3135
# Item count in the JSON file after save: 3136
# Item count in the JSON file after save: 3137
# Item count in the JSON file after save: 3138
# Item count in the JSON file after save: 3139
# Processing item number: 1248
# Question count : 5
# Item count in the JSON file after save: 3140
# Item count in the JSON file after save: 3141
# Item count in the JSON file after save: 3142
# Item count in the JSON file after save: 3143
# Item count in the JSON file after save: 3144
# Processing item number: 1249
# Processing item number: 1250
# Question count : 4
# Item count in the JSON file after save: 3145
# Item count in the JSON file after save: 3146
# Item count in the JSON file after save: 3147
# Item count in the JSON file after save: 3148
# Processing item number: 1251
# Question count : 2
# Item count in the JSON file after save: 3149
# Item count in the JSON file after save: 3150
# Processing item number: 1252
# Question count : 7
# Item count in the JSON file after save: 3151
# Item count in the JSON file after save: 3152
# Item count in the JSON file after save: 3153
# Item count in the JSON file after save: 3154
# Item count in the JSON file after save: 3155
# Item count in the JSON file after save: 3156
# Item count in the JSON file after save: 3157
# Processing item number: 1253
# Question count : 1
# Item count in the JSON file after save: 3158
# Processing item number: 1254
# Question count : 2
# Item count in the JSON file after save: 3159
# Item count in the JSON file after save: 3160
# Processing item number: 1255
# Question count : 5
# Item count in the JSON file after save: 3161
# Item count in the JSON file after save: 3162
# Item count in the JSON file after save: 3163
# Item count in the JSON file after save: 3164
# Item count in the JSON file after save: 3165
# Processing item number: 1256
# Question count : 5
# Item count in the JSON file after save: 3166
# Item count in the JSON file after save: 3167
# Item count in the JSON file after save: 3168
# Item count in the JSON file after save: 3169
# Item count in the JSON file after save: 3170
# Processing item number: 1257
# Question count : 3
# Item count in the JSON file after save: 3171
# Item count in the JSON file after save: 3172
# Item count in the JSON file after save: 3173
# Processing item number: 1258
# Processing item number: 1259
# Question count : 5
# Item count in the JSON file after save: 3174
# Item count in the JSON file after save: 3175
# Item count in the JSON file after save: 3176
# Item count in the JSON file after save: 3177
# Item count in the JSON file after save: 3178
# Processing item number: 1260
# Question count : 2
# Item count in the JSON file after save: 3179
# Item count in the JSON file after save: 3180
# Processing item number: 1261
# Processing item number: 1262
# Question count : 3
# Item count in the JSON file after save: 3181
# Item count in the JSON file after save: 3182
# Item count in the JSON file after save: 3183
# Processing item number: 1263
# Processing item number: 1264
# Question count : 3
# Item count in the JSON file after save: 3184
# Item count in the JSON file after save: 3185
# Item count in the JSON file after save: 3186
# Processing item number: 1265
# Question count : 4
# Item count in the JSON file after save: 3187
# Item count in the JSON file after save: 3188
# Item count in the JSON file after save: 3189
# Item count in the JSON file after save: 3190
# Processing item number: 1266
# Question count : 5
# Item count in the JSON file after save: 3191
# Item count in the JSON file after save: 3192
# Item count in the JSON file after save: 3193
# Item count in the JSON file after save: 3194
# Item count in the JSON file after save: 3195
# Processing item number: 1267
# Question count : 5
# Item count in the JSON file after save: 3196
# Item count in the JSON file after save: 3197
# Item count in the JSON file after save: 3198
# Item count in the JSON file after save: 3199
# Item count in the JSON file after save: 3200
# Processing item number: 1268
# Processing item number: 1269
# Question count : 4
# Item count in the JSON file after save: 3201
# Item count in the JSON file after save: 3202
# Item count in the JSON file after save: 3203
# Item count in the JSON file after save: 3204
# Processing item number: 1270
# Question count : 1
# Item count in the JSON file after save: 3205
# Processing item number: 1271
# Processing item number: 1272
# Question count : 1
# Item count in the JSON file after save: 3206
# Processing item number: 1273
# Question count : 4
# Item count in the JSON file after save: 3207
# Item count in the JSON file after save: 3208
# Item count in the JSON file after save: 3209
# Item count in the JSON file after save: 3210
# Processing item number: 1274
# Processing item number: 1275
# Question count : 4
# Item count in the JSON file after save: 3211
# Item count in the JSON file after save: 3212
# Item count in the JSON file after save: 3213
# Item count in the JSON file after save: 3214
# Processing item number: 1276
# Question count : 4
# Item count in the JSON file after save: 3215
# Item count in the JSON file after save: 3216
# Item count in the JSON file after save: 3217
# Item count in the JSON file after save: 3218
# Processing item number: 1277
# Processing item number: 1278
# Question count : 5
# Item count in the JSON file after save: 3219
# Item count in the JSON file after save: 3220
# Item count in the JSON file after save: 3221
# Item count in the JSON file after save: 3222
# Item count in the JSON file after save: 3223
# Processing item number: 1279
# Question count : 5
# Item count in the JSON file after save: 3224
# Item count in the JSON file after save: 3225
# Item count in the JSON file after save: 3226
# Item count in the JSON file after save: 3227
# Item count in the JSON file after save: 3228
# Processing item number: 1280
# Question count : 1
# Item count in the JSON file after save: 3229
# Processing item number: 1281
# Processing item number: 1282
# Question count : 4
# Item count in the JSON file after save: 3230
# Item count in the JSON file after save: 3231
# Item count in the JSON file after save: 3232
# Item count in the JSON file after save: 3233
# Processing item number: 1283
# Question count : 4
# Item count in the JSON file after save: 3234
# Item count in the JSON file after save: 3235
# Item count in the JSON file after save: 3236
# Item count in the JSON file after save: 3237
# Processing item number: 1284
# Question count : 3
# Item count in the JSON file after save: 3238
# Item count in the JSON file after save: 3239
# Item count in the JSON file after save: 3240
# Processing item number: 1285
# Processing item number: 1286
# Question count : 3
# Item count in the JSON file after save: 3241
# Item count in the JSON file after save: 3242
# Item count in the JSON file after save: 3243
# Processing item number: 1287
# Question count : 4
# Item count in the JSON file after save: 3244
# Item count in the JSON file after save: 3245
# Item count in the JSON file after save: 3246
# Item count in the JSON file after save: 3247
# Processing item number: 1288
# Processing item number: 1289
# Question count : 3
# Item count in the JSON file after save: 3248
# Item count in the JSON file after save: 3249
# Item count in the JSON file after save: 3250
# Processing item number: 1290
# Question count : 3
# Item count in the JSON file after save: 3251
# Item count in the JSON file after save: 3252
# Item count in the JSON file after save: 3253
# Processing item number: 1291
# Question count : 4
# Item count in the JSON file after save: 3254
# Item count in the JSON file after save: 3255
# Item count in the JSON file after save: 3256
# Item count in the JSON file after save: 3257
# Questions and contexts saved to /content/drive/Othercomputers/MBZUAI/MBZUAI/ADGM-Project/ADGM Docs Study/ArtificialDataset/COBS_VER15.150823_questions_contexts.json
